# %%
file_path="C:\\Users\\Bhuban Khadka\\Documents\\bhumika.txt"
file=open(file_path)
file.read
# Out:
# <function TextIOWrapper.read(size=-1, /)>

# %%
dir(

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Bhuban Khadka\\Desktop'

# %%
file_path="C:\\Users\\Bhuban Khadka\\Documents\\bhumika.txt"
file=open(file_path,encoding='utf-8-sig')
print(file.read())
# Out:
# Submission Number:-810068672197
# कृपया आफ्नो Username, Password र Submission Number सुरक्षित राख्नुहोस्। यहि Username र Password तपाईले आन्तरिक राजस्व विभागको अन्य E-SYSTEM हरु मा पनि प्रयोग गर्न सकिने छ।
# सम्पूर्ण आवश्यक विवरण, फोटो र परिचयपत्र प्रविष्ट गरीसकेपछि सेभ र सबमिट Button थिच्नुहोस् र "Print Form" मा क्लिक गरी प्रिन्ट निकाल्नुहोस्। सोको एक प्रति वा Submission Number लिई सम्वन्धित आन्तकरिक राजस्व कार्यालयमा सम्पर्क गरी आफ्नो व्यक्तिगत/व्यवसाइक स्थायी लेखा नम्बर प्रमाणपत्र प्राप्त गर्नुहोस्।

# %%
#data file and python file both are in same location
#file_name+<extension>
#no need to provide location
file_path="bhumika.txt"
file=open(file_path,encoding='utf-8-sig')
print(file.read())
# Out:
# Submission Number:-810068672197
# कृपया आफ्नो Username, Password र Submission Number सुरक्षित राख्नुहोस्। यहि Username र Password तपाईले आन्तरिक राजस्व विभागको अन्य E-SYSTEM हरु मा पनि प्रयोग गर्न सकिने छ।
# सम्पूर्ण आवश्यक विवरण, फोटो र परिचयपत्र प्रविष्ट गरीसकेपछि सेभ र सबमिट Button थिच्नुहोस् र "Print Form" मा क्लिक गरी प्रिन्ट निकाल्नुहोस्। सोको एक प्रति वा Submission Number लिई सम्वन्धित आन्तकरिक राजस्व कार्यालयमा सम्पर्क गरी आफ्नो व्यक्तिगत/व्यवसाइक स्थायी लेखा नम्बर प्रमाणपत्र प्राप्त गर्नुहोस्।

# %% [markdown]
# $change directory$

# %%
dir(os)
# Out:
# ['DirEntry',
#  'EX_OK',
#  'F_OK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_AddedDllDirectory',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_methods',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_walk_symlinks_as_files',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'add_dll_directory',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
#  'dup2',
#  'environ',
#  'error',
#  'execl',
#  'execle',
#  'execlp',
#  'execlpe',
#  'execv',
#  'execve',
#  'execvp',
#  'execvpe',
#  'extsep',
#  'fdopen',
#  'fsdecode',
#  'fsencode',
#  'fspath',
#  'fstat',
#  'fsync',
#  'ftruncate',
#  'get_blocking',
#  'get_exec_path',
#  'get_handle_inheritable',
#  'get_inheritable',
#  'get_terminal_size',
#  'getcwd',
#  'getcwdb',
#  'getenv',
#  'getlogin',
#  'getpid',
#  'getppid',
#  'isatty',
#  'kill',
#  'linesep',
#  'link',
#  'listdir',
#  'listdrives',
#  'listmounts',
#  'listvolumes',
#  'lseek',
#  'lstat',
#  'makedirs',
#  'mkdir',
#  'name',
#  'open',
#  'pardir',
#  'path',
#  'pathsep',
#  'pipe',
#  'popen',
#  'putenv',
#  'read',
#  'readlink',
#  'remove',
#  'removedirs',
#  'rename',
#  'renames',
#  'replace',
#  'rmdir',
#  'scandir',
#  'sep',
#  'set_blocking',
#  'set_handle_inheritable',
#  'set_inheritable',
#  'spawnl',
#  'spawnle',
#  'spawnv',
#  'spawnve',
#  'st',
#  'startfile',
#  'stat',
#  'stat_result',
#  'statvfs_result',
#  'strerror',
#  'supports_bytes_environ',
#  'supports_dir_fd',
#  'supports_effective_ids',
#  'supports_fd',
#  'supports_follow_symlinks',
#  'symlink',
#  'sys',
#  'system',
#  'terminal_size',
#  'times',
#  'times_result',
#  'truncate',
#  'umask',
#  'uname_result',
#  'unlink',
#  'unsetenv',
#  'urandom',
#  'utime',
#  'waitpid',
#  'waitstatus_to_exitcode',
#  'walk',
#  'write']

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Bhuban Khadka\\Desktop'

# %%
path="C:\\Users\\Bhuban Khadka\\Downloads"
os.chdir(path)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Bhuban Khadka\\Downloads'

# %%
file_path="C:\\Users\\Bhuban Khadka\\Documents\\bhumika.txt"
file=open(file_path,encoding='utf-8-sig')
print(file.read())
# Out:
# Submission Number:-810068672197
# कृपया आफ्नो Username, Password र Submission Number सुरक्षित राख्नुहोस्। यहि Username र Password तपाईले आन्तरिक राजस्व विभागको अन्य E-SYSTEM हरु मा पनि प्रयोग गर्न सकिने छ।
# सम्पूर्ण आवश्यक विवरण, फोटो र परिचयपत्र प्रविष्ट गरीसकेपछि सेभ र सबमिट Button थिच्नुहोस् र "Print Form" मा क्लिक गरी प्रिन्ट निकाल्नुहोस्। सोको एक प्रति वा Submission Number लिई सम्वन्धित आन्तकरिक राजस्व कार्यालयमा सम्पर्क गरी आफ्नो व्यक्तिगत/व्यवसाइक स्थायी लेखा नम्बर प्रमाणपत्र प्राप्त गर्नुहोस्।

# %%
path='C:\\Users\\Bhuban Khadka\\Desktop'
os.chdir(path)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Bhuban Khadka\\Desktop'

# %%
file_path="C:\\Users\\Bhuban Khadka\\Documents\\bhumika.txt"
file=open(file_path,encoding='utf-8-sig')
print(file.read())
# Out:
# Submission Number:-810068672197
# कृपया आफ्नो Username, Password र Submission Number सुरक्षित राख्नुहोस्। यहि Username र Password तपाईले आन्तरिक राजस्व विभागको अन्य E-SYSTEM हरु मा पनि प्रयोग गर्न सकिने छ।
# सम्पूर्ण आवश्यक विवरण, फोटो र परिचयपत्र प्रविष्ट गरीसकेपछि सेभ र सबमिट Button थिच्नुहोस् र "Print Form" मा क्लिक गरी प्रिन्ट निकाल्नुहोस्। सोको एक प्रति वा Submission Number लिई सम्वन्धित आन्तकरिक राजस्व कार्यालयमा सम्पर्क गरी आफ्नो व्यक्तिगत/व्यवसाइक स्थायी लेखा नम्बर प्रमाणपत्र प्राप्त गर्नुहोस्।

# %% [markdown]
# $with$

# %%
file.read()
# Out:
# ''

# %%
file
# Out:
# <_io.TextIOWrapper name='C:\\Users\\Bhuban Khadka\\Documents\\bhumika.txt' mode='r' encoding='utf-8-sig'>

# %%
# file_path="C:\\Users\\Bhuban Khadka\\Documents\\bhumika.txt"
# #file=open(file_path,encoding='utf-8-sig')
# #print(file.read())
# with open(file_path) as file:
#     data=file.read()

# %%
file_path="bhumika.txt"
# file=open(file_path,encoding='utf-8-sig')
# print(file.read
with open(file_path, encoding='utf-8-sig') as file:
    data=file.read()

# %% [markdown]
# print(data)

# %%
#m1
file_path="C:\\Users\\Bhuban Khadka\\Documents\\bhumika.txt"
file=open(file_path,encoding='utf-8-sig')
print(file.read())
#m2
file_path="bhumika.txt"
file=open(file_path,encoding='utf-8-sig')
print(file.read())
#m3
file_path="bhumika.txt"
with open(file_path, encoding='utf-8-sig') as file:
    data=file.read()

# %%
file_path="bhumika.txt"
with open(file_path, encoding='utf-8-sig') as file:
    for i in file.read():
        print(i)
# Out:
# S
# u
# b
# m
# i
# s
# s
# i
# o
# n
#
# N
# u
# m
# b
# e
# r
# :
# -
# 8
# 1
# 0
# 0
# 6
# 8
# 6
# 7
# 2
# 1
# 9
# 7
#
#
# क
# ृ
# प
# य
# ा
#
# आ
# फ
# ्
# न
# ो
#
# U
# s
# e
# r
# n
# a
# m
# e
# ,
#
# P
# a
# s
# s
# w
# o
# r
# d
#
# र
#
# S
# u
# b
# m
# i
# s
# s
# i
# o
# n
#
# N
# u
# m
# b
# e
# r
#
# स
# ु
# र
# क
# ्
# ष
# ि
# त
#
# र
# ा
# ख
# ्
# न
# ु
# ह
# ो
# स
# ्
# ।
#
# य
# ह
# ि
#
# U
# s
# e
# r
# n
# a
# m
# e
#
# र
#
# P
# a
# s
# s
# w
# o
# r
# d
#
# त
# प
# ा
# ई
# ल
# े
#
# आ
# न
# ्
# त
# र
# ि
# क
#
# र
# ा
# ज
# स
# ्
# व
#
# व
# ि
# भ
# ा
# ग
# क
# ो
#
# अ
# न
# ्
# य
#
# E
# -
# S
# Y
# S
# T
# E
# M
#
# ह
# र
# ु
#
# म
# ा
#
# प
# न
# ि
#
# प
# ्
# र
# य
# ो
# ग
#
# ग
# र
# ्
# न
#
# स
# क
# ि
# न
# े
#
# छ
# ।
#
#
# स
# म
# ्
# प
# ू
# र
# ्
# ण
#
# आ
# व
# श
# ्
# य
# क
#
# व
# ि
# व
# र
# ण
# ,
#
# फ
# ो
# ट
# ो
#
# र
#
# प
# र
# ि
# च
# य
# प
# त
# ्
# र
#
# प
# ्
# र
# व
# ि
# ष
# ्
# ट
#
# ग
# र
# ी
# स
# क
# े
# प
# छ
# ि
#
# स
# े
# भ
#
# र
#
# स
# ब
# म
# ि
# ट
#
# B
# u
# t
# t
# o
# n
#
# थ
# ि
# च
# ्
# न
# ु
# ह
# ो
# स
# ्
#
# र
#
# "
# P
# r
# i
# n
# t
#
# F
# o
# r
# m
# "
#
# म
# ा
#
# क
# ्
# ल
# ि
# क
#
# ग
# र
# ी
#
# प
# ्
# र
# ि
# न
# ्
# ट
#
# न
# ि
# क
# ा
# ल
# ्
# न
# ु
# ह
# ो
# स
# ्
# ।
#
# स
# ो
# क
# ो
#
# ए
# क
#
# प
# ्
# र
# त
# ि
#
# व
# ा
#
# S
# u
# b
# m
# i
# s
# s
# i
# o
# n
#
# N
# u
# m
# b
# e
# r
#
# ल
# ि
# ई
#
# स
# म
# ्
# व
# न
# ्
# ध
# ि
# त
#
# आ
# न
# ्
# त
# क
# र
# ि
# क
#
# र
# ा
# ज
# स
# ्
# व
#
# क
# ा
# र
# ्
# य
# ा
# ल
# य
# म
# ा
#
# स
# म
# ्
# प
# र
# ्
# क
#
# ग
# र
# ी
#
# आ
# फ
# ्
# न
# ो
#
# व
# ्
# य
# क
# ्
# त
# ि
# ग
# त
# /
# व
# ्
# य
# व
# स
# ा
# इ
# क
#
# स
# ्
# थ
# ा
# य
# ी
#
# ल
# े
# ख
# ा
#
# न
# म
# ्
# ब
# र
#
# प
# ्
# र
# म
# ा
# ण
# प
# त
# ्
# र
#
# प
# ्
# र
# ा
# प
# ्
# त
#
# ग
# र
# ्
# न
# ु
# ह
# ो
# स
# ्
# ।

# %%
len(data)
# Out:
# 503

# %%
for i in data:
    print(i)
# Out:
# S
# u
# b
# m
# i
# s
# s
# i
# o
# n
#
# N
# u
# m
# b
# e
# r
# :
# -
# 8
# 1
# 0
# 0
# 6
# 8
# 6
# 7
# 2
# 1
# 9
# 7
#
#
# क
# ृ
# प
# य
# ा
#
# आ
# फ
# ्
# न
# ो
#
# U
# s
# e
# r
# n
# a
# m
# e
# ,
#
# P
# a
# s
# s
# w
# o
# r
# d
#
# र
#
# S
# u
# b
# m
# i
# s
# s
# i
# o
# n
#
# N
# u
# m
# b
# e
# r
#
# स
# ु
# र
# क
# ्
# ष
# ि
# त
#
# र
# ा
# ख
# ्
# न
# ु
# ह
# ो
# स
# ्
# ।
#
# य
# ह
# ि
#
# U
# s
# e
# r
# n
# a
# m
# e
#
# र
#
# P
# a
# s
# s
# w
# o
# r
# d
#
# त
# प
# ा
# ई
# ल
# े
#
# आ
# न
# ्
# त
# र
# ि
# क
#
# र
# ा
# ज
# स
# ्
# व
#
# व
# ि
# भ
# ा
# ग
# क
# ो
#
# अ
# न
# ्
# य
#
# E
# -
# S
# Y
# S
# T
# E
# M
#
# ह
# र
# ु
#
# म
# ा
#
# प
# न
# ि
#
# प
# ्
# र
# य
# ो
# ग
#
# ग
# र
# ्
# न
#
# स
# क
# ि
# न
# े
#
# छ
# ।
#
#
# स
# म
# ्
# प
# ू
# र
# ्
# ण
#
# आ
# व
# श
# ्
# य
# क
#
# व
# ि
# व
# र
# ण
# ,
#
# फ
# ो
# ट
# ो
#
# र
#
# प
# र
# ि
# च
# य
# प
# त
# ्
# र
#
# प
# ्
# र
# व
# ि
# ष
# ्
# ट
#
# ग
# र
# ी
# स
# क
# े
# प
# छ
# ि
#
# स
# े
# भ
#
# र
#
# स
# ब
# म
# ि
# ट
#
# B
# u
# t
# t
# o
# n
#
# थ
# ि
# च
# ्
# न
# ु
# ह
# ो
# स
# ्
#
# र
#
# "
# P
# r
# i
# n
# t
#
# F
# o
# r
# m
# "
#
# म
# ा
#
# क
# ्
# ल
# ि
# क
#
# ग
# र
# ी
#
# प
# ्
# र
# ि
# न
# ्
# ट
#
# न
# ि
# क
# ा
# ल
# ्
# न
# ु
# ह
# ो
# स
# ्
# ।
#
# स
# ो
# क
# ो
#
# ए
# क
#
# प
# ्
# र
# त
# ि
#
# व
# ा
#
# S
# u
# b
# m
# i
# s
# s
# i
# o
# n
#
# N
# u
# m
# b
# e
# r
#
# ल
# ि
# ई
#
# स
# म
# ्
# व
# न
# ्
# ध
# ि
# त
#
# आ
# न
# ्
# त
# क
# र
# ि
# क
#
# र
# ा
# ज
# स
# ्
# व
#
# क
# ा
# र
# ्
# य
# ा
# ल
# य
# म
# ा
#
# स
# म
# ्
# प
# र
# ्
# क
#
# ग
# र
# ी
#
# आ
# फ
# ्
# न
# ो
#
# व
# ्
# य
# क
# ्
# त
# ि
# ग
# त
# /
# व
# ्
# य
# व
# स
# ा
# इ
# क
#
# स
# ्
# थ
# ा
# य
# ी
#
# ल
# े
# ख
# ा
#
# न
# म
# ्
# ब
# र
#
# प
# ्
# र
# म
# ा
# ण
# प
# त
# ्
# र
#
# प
# ्
# र
# ा
# प
# ्
# त
#
# ग
# र
# ्
# न
# ु
# ह
# ो
# स
# ्
# ।

# %%
#to know the number of lines use:enumerate
file_path="bhumika.txt"
file=open(file_path,encoding='utf-8-sig')
for i in file:
    print(i)#before reading you'll have lines
#if you want to see lines,work on open()
#if you want to see the characters,use read()
# Out:
# Submission Number:-810068672197
#
# कृपया आफ्नो Username, Password र Submission Number सुरक्षित राख्नुहोस्। यहि Username र Password तपाईले आन्तरिक राजस्व विभागको अन्य E-SYSTEM हरु मा पनि प्रयोग गर्न सकिने छ।
#
# सम्पूर्ण आवश्यक विवरण, फोटो र परिचयपत्र प्रविष्ट गरीसकेपछि सेभ र सबमिट Button थिच्नुहोस् र "Print Form" मा क्लिक गरी प्रिन्ट निकाल्नुहोस्। सोको एक प्रति वा Submission Number लिई सम्वन्धित आन्तकरिक राजस्व कार्यालयमा सम्पर्क गरी आफ्नो व्यक्तिगत/व्यवसाइक स्थायी लेखा नम्बर प्रमाणपत्र प्राप्त गर्नुहोस्।

# %% [markdown]
# $enumerate$

# %%
#q1:get number of lines
file_path="bhumika.txt"
file=open(file_path,encoding='utf-8-sig')
count=0
for i in file:
    count+=1
print(count)
# Out:
# 3

# %%
file_path="bhumika.txt"
file=open(file_path,encoding='utf-8-sig')
for index,line in enumerate(file):
    print(index,line)
# Out:
# 0 Submission Number:-810068672197
#
# 1 कृपया आफ्नो Username, Password र Submission Number सुरक्षित राख्नुहोस्। यहि Username र Password तपाईले आन्तरिक राजस्व विभागको अन्य E-SYSTEM हरु मा पनि प्रयोग गर्न सकिने छ।
#
# 2 सम्पूर्ण आवश्यक विवरण, फोटो र परिचयपत्र प्रविष्ट गरीसकेपछि सेभ र सबमिट Button थिच्नुहोस् र "Print Form" मा क्लिक गरी प्रिन्ट निकाल्नुहोस्। सोको एक प्रति वा Submission Number लिई सम्वन्धित आन्तकरिक राजस्व कार्यालयमा सम्पर्क गरी आफ्नो व्यक्तिगत/व्यवसाइक स्थायी लेखा नम्बर प्रमाणपत्र प्राप्त गर्नुहोस्।

# %%
#m1
file_path="bhumika.txt"
file=open(file_path,encoding='utf-8-sig')
for index,line in enumerate(file):
    pass
number=index+1
print(number)
# Out:
# 3

# %%
#m2
file_path="bhumika.txt"
file=open(file_path,encoding='utf-8-sig')
l1=[index for index,_ in enumerate(file)]
l1
#here line are notrequired
# Out:
# [0, 1, 2]

# %%
#q3)print first 10 lines
file_path="bhumika.txt"
file=open(file_path,encoding='utf-8-sig')
for index,line in enumerate(file):
    print(index,line)
    if index==3:
        break
for index,line in enumerate(file):
    if index<10:
        print(index,line)
# Out:
# 0 Submission Number:-810068672197
#
# 1 कृपया आफ्नो Username, Password र Submission Number सुरक्षित राख्नुहोस्। यहि Username र Password तपाईले आन्तरिक राजस्व विभागको अन्य E-SYSTEM हरु मा पनि प्रयोग गर्न सकिने छ।
#
# 2 सम्पूर्ण आवश्यक विवरण, फोटो र परिचयपत्र प्रविष्ट गरीसकेपछि सेभ र सबमिट Button थिच्नुहोस् र "Print Form" मा क्लिक गरी प्रिन्ट निकाल्नुहोस्। सोको एक प्रति वा Submission Number लिई सम्वन्धित आन्तकरिक राजस्व कार्यालयमा सम्पर्क गरी आफ्नो व्यक्तिगत/व्यवसाइक स्थायी लेखा नम्बर प्रमाणपत्र प्राप्त गर्नुहोस्।

# %%
#q3 make all lines in same alignment
file_path="bhumika.txt"
file=open(file_path,encoding='utf-8-sig')
    
for line in file:
    print(line.strip())
# Out:
# Submission Number:-810068672197
# कृपया आफ्नो Username, Password र Submission Number सुरक्षित राख्नुहोस्। यहि Username र Password तपाईले आन्तरिक राजस्व विभागको अन्य E-SYSTEM हरु मा पनि प्रयोग गर्न सकिने छ।
# सम्पूर्ण आवश्यक विवरण, फोटो र परिचयपत्र प्रविष्ट गरीसकेपछि सेभ र सबमिट Button थिच्नुहोस् र "Print Form" मा क्लिक गरी प्रिन्ट निकाल्नुहोस्। सोको एक प्रति वा Submission Number लिई सम्वन्धित आन्तकरिक राजस्व कार्यालयमा सम्पर्क गरी आफ्नो व्यक्तिगत/व्यवसाइक स्थायी लेखा नम्बर प्रमाणपत्र प्राप्त गर्नुहोस्।

# %%
#q5 extract lines those who are staring with 'from'
#and keep in a list
#and get the count of list
import os

folder_path = "C:\\Users\\Bhuban Khadka\\"
files = os.listdir(folder_path)

#print("Files in folder:")
for f in files:
    # for line in files:
    #     if line.startswith('From'):
    #         print(line)
